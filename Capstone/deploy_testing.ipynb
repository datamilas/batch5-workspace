# %%
import os
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio
import requests
import json
import numpy as np

#Connection info string:
#   "dbname=d4t5p4rbuaffmp host=ec2-52-31-201-170.eu-west-1.compute.amazonaws.com port=5432 user=dxyuvaxnhsadyc password=b97601133f15c1094f4297ba7be0f261a71298c7b5311d6616972d458341532c sslmode=require"
#Connection URL:

DATABASE_URL = "postgres://ewtzpgfuvhggye:72a146b70f8391f1d6ee42270d38b3ac634dcb13ebb506c23ffaa879c921cd87@ec2-54-228-95-1.eu-west-1.compute.amazonaws.com:5432/d2jolbgslv3h5k"

# %%
conn = psycopg2.connect(DATABASE_URL, sslmode='require')
data = sqlio.read_sql_query("SELECT * FROM prediction", conn)
conn.close ()

# Now data is a pandas dataframe having the results of above query.

data
# Out:
#     id observation_id                                        observation  \
# 0    1            105  {"admission_id": "105.0", "patient_id": 813178...
# 1    3          84417  {"admission_id": 84417, "patient_id": 62128908...
# 2    4         100530  {"admission_id": 100530, "patient_id": 2675520...
# 3    5          81601  {"admission_id": 81601, "patient_id": 10859448...
# 4    6          84159  {"admission_id": 84159, "patient_id": 11958805...
# 5    7          99843  {"admission_id": 99843, "patient_id": 21085353...
# 6    8         100354  {"admission_id": 100354, "patient_id": 2470472...
# 7    9          90078  {"admission_id": 90078, "patient_id": 77156334...
# 8   12          98980  {"admission_id": 98980, "patient_id": 11872641...
# 9   13          87832  {"admission_id": 87832, "patient_id": 85194756...
# 10  14          86463  {"admission_id": 86463, "patient_id": 47713626...
# 11  15          86723  {"admission_id": 86723, "patient_id": 12771115...
# ...

# %%
data_old=data.copy()

# %%
moment_1_trial  = pd.read_json("moment_1_trial.json")
moment_2_trial  = pd.read_json("moment_2_trial.json")

# %%
#url = 'http://localhost:5000/predict'
url = "https://capstone-amilas.herokuapp.com/predict"
for payload in moment_1_trial.data:
    r = requests.post(url, json = payload)
    print(r.text)
# Out:
# {"readmitted":"Yes"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"No"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"No"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"Yes"}
#
# {"readmitted":"No"}
#
# {"readmitted":"No","error":"ERROR: Admission ID: '92775' already exists"}
#
# {"readmitted":"No","error":"ERROR: Admission ID: '95835' already exists"}
#
# {"readmitted":"Yes","error":"ERROR: Admission ID: '85838' already exists"}
#
# {"readmitted":"Yes","error":"ERROR: Admission ID: '98262' already exists"}
#
# ...

# %%
#url = 'http://localhost:5000/update'
url = "https://capstone-amilas.herokuapp.com/update"
for payload in moment_2_trial.data:
    r = requests.post(url, json = payload)
    print(payload)
    print(r.text)
# Out:
# {'admission_id': 82679, 'readmitted': 'No'}
# {"error":"Admission ID: 82679 does not exist"}
#
# {'admission_id': 83311, 'readmitted': 'No'}
# {"admission_id":83311,"actual_readmitted":"No","predicted_readmitted":"Yes"}
#
# {'admission_id': 84417, 'readmitted': 'No'}
# {"admission_id":84417,"actual_readmitted":"No","predicted_readmitted":"No"}
#
# {'admission_id': 100530, 'readmitted': 'No'}
# {"admission_id":100530,"actual_readmitted":"No","predicted_readmitted":"Yes"}
#
# {'admission_id': 81601, 'readmitted': 'No'}
# {"admission_id":81601,"actual_readmitted":"No","predicted_readmitted":"No"}
#
# {'admission_id': 84159, 'readmitted': 'No'}
# {"admission_id":84159,"actual_readmitted":"No","predicted_readmitted":"No"}
#
# {'admission_id': 99843, 'readmitted': 'No'}
# {"admission_id":99843,"actual_readmitted":"No","predicted_readmitted":"No"}
#
# {'admission_id': 100354, 'readmitted': 'No'}
# {"admission_id":100354,"actual_readmitted":"No","predicted_readmitted":"No"}
#
# ...

# %%
def unit_test(test, url_to_use="local", endpoint = "predict"):
    if url_to_use == "local":
        if endpoint == "predict":
            url = 'http://localhost:5000/predict'
        elif endpoint == "update":
            url = 'http://localhost:5000/update'

    elif url_to_use == "app":
        if endpoint == "predict":
            url = "https://capstone-amilas.herokuapp.com/predict"
        elif endpoint == "update":
            url = "https://capstone-amilas.herokuapp.com/update"
    r = requests.post(url, json = test)
    print(r.text)

# %%
#test admission_id as string that can be converted to integer
test = moment_1_trial.iloc[0].data
url_to_use = "local"

test["admission_id"] = "105.0"
unit_test(test, url_to_use )
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.virtualenvs/capstone/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.virtualenvs/capstone/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~/.virtualenvs/capstone/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...

# %%
#test admission_id as string that can be converted to float, but not integer
test["admission_id"] = "105.55"
unit_test(test, url_to_use)
# Out:
# {
#   "error": "admission_id has to be integer"
# }

# %%
#test admission_id is non convertable string
test["admission_id"] = "12ll"
unit_test(test, url_to_use )
# Out:
# {
#   "error": "admission_id has to be integer"
# }

# %%
#test admission_id as nan
test["admission_id"] = "nan"
unit_test(test, url_to_use)
# Out:
# {
#   "error": "Value of admission_id is required"
# }

# %%
#test admission_id is float
test["admission_id"] = 5.33
unit_test(test, url_to_use)
# Out:
# {
#   "error": "admission_id has to be integer"
# }

# %%
#test admission_id is float ending with .0
test["admission_id"] = 5.0
unit_test(test, url_to_use)
# Out:
# {
#   "readmitted": "Yes",
#   "error": "ERROR: Admission ID: '5' already exists"
# }

# %%
#test admission_id is int that is already in the database
test["admission_id"] = 5
unit_test(test, url_to_use)
# Out:
# {
#   "readmitted": "Yes",
#   "error": "ERROR: Admission ID: '5' already exists"
# }

# %%
test_no_admission = dict(test)
del test_no_admission['admission_id']

# %%
#test admission_id is missing
unit_test(test_no_admission, url_to_use)
# Out:
# {
#   "error": "Field `admission_id` missing from request: {'patient_id': 81317898, 'race': 'Caucasian', 'gender': 'Male', 'age': None, 'weight': '?', 'admission_type_code': 3.0, 'discharge_disposition_code': 3.0, 'admission_source_code': 1, 'time_in_hospital': 7, 'payer_code': 'MC', 'medical_specialty': 'Family/GeneralPractice', 'has_prosthesis': False, 'complete_vaccination_status': 'Complete', 'num_lab_procedures': 44.0, 'num_procedures': 1, 'num_medications': 13.0, 'number_outpatient': 0, 'number_emergency': 0, 'number_inpatient': 2, 'diag_1': '585', 'diag_2': '491', 'diag_3': '276', 'number_diagnoses': 9, 'blood_type': 'O+', 'hemoglobin_level': 15.6, 'blood_transfusion': False, 'max_glu_serum': 'None', 'A1Cresult': 'None', 'diuretics': 'No', 'insulin': 'Yes', 'change': 'Ch', 'diabetesMed': 'Yes'}"
# }

# %%
#test admission_id is int, update
test_update = moment_2_trial.iloc[0].data
endpoint = "update"

test_update["admission_id"] = 5
unit_test(test_update, url_to_use, endpoint)
# Out:
# {
#   "admission_id": 5,
#   "actual_readmitted": "No",
#   "predicted_readmitted": "Yes"
# }

# %%
#test admission_id is convertable str, update

test_update["admission_id"] = "5"
unit_test(test_update, url_to_use, endpoint)
# Out:
# {
#   "admission_id": 5,
#   "actual_readmitted": "No",
#   "predicted_readmitted": "Yes"
# }

# %%
#test admission_id is convertable str, update

test_update["admission_id"] = "5.0"
unit_test(test_update, url_to_use, endpoint)
# Out:
# {
#   "admission_id": 5,
#   "actual_readmitted": "No",
#   "predicted_readmitted": "Yes"
# }

# %%
#test admission_id is non convertable str, update

test_update["admission_id"] = "5.055"
unit_test(test_update, url_to_use, endpoint)
# Out:
# {
#   "error": "admission_id has to be integer"
# }

# %%
#test admission_id is non convertable str, update

test_update["admission_id"] = "55sss"
unit_test(test_update, url_to_use, endpoint)
# Out:
# {
#   "error": "admission_id has to be integer"
# }

# %%
#test admission_id is convertable float, update

test_update["admission_id"] = 5.0
unit_test(test_update, url_to_use, endpoint)
# Out:
# {
#   "admission_id": 5,
#   "actual_readmitted": "No",
#   "predicted_readmitted": "Yes"
# }

# %%
#test admission_id is non-convertable float, update

test_update["admission_id"] = 5.5
unit_test(test_update, url_to_use, endpoint)
# Out:
# {
#   "error": "admission_id has to be integer"
# }

# %%
#test admission_id is missing

test_update_no_admission ={'readmitted': 'No'}
unit_test(test_update_no_admission, url_to_use, endpoint)
# Out:
# {
#   "error": "Field `admission_id` missing from request: {'readmitted': 'No'}"
# }

# %%
test["num_procedures"] = 15.0
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": "3.0"
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "1.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["num_procedures"] = 1500000.0
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": NaN
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "7.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": NaN
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["num_procedures"] = 15.15
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": "3.0"
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "1.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": NaN
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["num_procedures"] = "15"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": "3.0"
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "1.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["num_procedures"] = "15.0"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": "3.0"
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "1.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["admission_type_code"] = "1.0"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": "1.0"
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "1.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["admission_type_code"] = "4.0"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": "Other"
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "1.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["admission_type_code"] = "fdfd"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": NaN
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "1.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["admission_source_code"] = "fdfd"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": NaN
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": NaN
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["admission_source_code"] = 7
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": NaN
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "7.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["has_prosthesis"] = "True"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": NaN
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "7.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": true
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["has_prosthesis"] = "1.00000"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": NaN
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "7.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": true
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
test["has_prosthesis"] = "1.00010"
unit_test(test, url_to_use)
# Out:
# {
#   "race": {
#     "0": "Caucasian"
#   },
#   "gender": {
#     "0": "Male"
#   },
#   "admission_type_code": {
#     "0": NaN
#   },
#   "discharge_disposition_code": {
#     "0": "3.0"
#   },
#   "admission_source_code": {
#     "0": "7.0"
#   },
#   "time_in_hospital": {
#     "0": 7.0
#   },
#   "has_prosthesis": {
#     "0": false
#   },
#   "complete_vaccination_status": {
#     "0": "Complete"
#   },
#   "num_lab_procedures": {
#     "0": 44.0
#   },
#   "num_procedures": {
#     "0": 15.0
#   },
#   "num_medications": {
#     "0": 13.0
#   },
#   "number_outpatient": {
#     "0": 0.0
#   },
#   "number_emergency": {
#     "0": 0.0
#   },
#   "number_inpatient": {
#     "0": 2.0
#   },
#   "number_diagnoses": {
#     "0": 9.0
#   },
#   "hemoglobin_level": {
#     "0": 15.6
#   },
#   "blood_transfusion": {
#     "0": false
#   },
#   "max_glu_serum": {
#     "0": "None"
#   },
#   "A1Cresult": {
#     "0": "None"
#   },
#   "diuretics": {
#     "0": "No"
#   },
# ...

# %%
! curl -X POST https://capstone-amilas.herokuapp.com/predict -d '{"patient_id": 0, "race": "string", "gender": "string", "age": "string", "weight": "string", "admission_type_code": 0, "discharge_disposition_code": 0,"admission_source_code": 0,"time_in_hospital": 0,"payer_code": "string","medical_specialty": "string","has_prosthesis": true,"complete_vaccination_status": "string","num_lab_procedures": 0,"num_procedures": 0,"num_medications": 0,"number_outpatient": 0,"number_emergency": 0,"number_inpatient": 0,"diag_1": "string","diag_2": "string","diag_3": "string","number_diagnoses": 0,"blood_type": "string","hemoglobin_level": 0,"blood_transfusion": true,"max_glu_serum": "string","A1Cresult": "string","diuretics": "string","insulin": "string","change": "string","diabetesMed": "string"}' -H "Content-Type:application/json"
# Out:
# {"error":"Field `admission_id` missing from request: {'patient_id': 0, 'race': 'string', 'gender': 'string', 'age': 'string', 'weight': 'string', 'admission_type_code': 0, 'discharge_disposition_code': 0, 'admission_source_code': 0, 'time_in_hospital': 0, 'payer_code': 'string', 'medical_specialty': 'string', 'has_prosthesis': True, 'complete_vaccination_status': 'string', 'num_lab_procedures': 0, 'num_procedures': 0, 'num_medications': 0, 'number_outpatient': 0, 'number_emergency': 0, 'number_inpatient': 0, 'diag_1': 'string', 'diag_2': 'string', 'diag_3': 'string', 'number_diagnoses': 0, 'blood_type': 'string', 'hemoglobin_level': 0, 'blood_transfusion': True, 'max_glu_serum': 'string', 'A1Cresult': 'string', 'diuretics': 'string', 'insulin': 'string', 'change': 'string', 'diabetesMed': 'string'}"}

# %%
! curl -X POST https://capstone-amilas.herokuapp.com/predict -d '{"admission_id": 20, "patient_id": 0, "race": "string", "gender": "string", "age": "string", "weight": "string", "admission_type_code": 0, "discharge_disposition_code": 11,"admission_source_code": 0,"time_in_hospital": 0,"payer_code": "string","medical_specialty": "string","has_prosthesis": true,"complete_vaccination_status": "string","num_lab_procedures": 0,"num_procedures": 0,"num_medications": 0,"number_outpatient": 0,"number_emergency": 0,"number_inpatient": 0,"diag_1": "string","diag_2": "string","diag_3": "string","number_diagnoses": 0,"blood_type": "string","hemoglobin_level": 0,"blood_transfusion": true,"max_glu_serum": "string","A1Cresult": "string","diuretics": "string","insulin": "string","change": "string","diabetesMed": "string"}' -H "Content-Type:application/json"
# Out:
# {"readmitted":"No","error":"ERROR: Admission ID: '20' already exists"}

# %%
! curl -X POST https://capstone-amilas.herokuapp.com/predict -d '{"patient_id": 0, "race": "string", "gender": "string", "age": "string", "weight": "string", "admission_type_code": 0, "discharge_disposition_code": 0,"admission_source_code": 0,"time_in_hospital": 0,"payer_code": "string","medical_specialty": "string","has_prosthesis": true,"complete_vaccination_status": "string","num_lab_procedures": 0,"num_procedures": 0,"num_medications": 0,"number_outpatient": 0,"number_emergency": 0,"number_inpatient": 0,"diag_1": "string","diag_2": "string","diag_3": "string","number_diagnoses": 0,"blood_type": "string","hemoglobin_level": 0,"blood_transfusion": true,"max_glu_serum": "string","A1Cresult": "string","diuretics": "string","insulin": "string","change": "string","diabetesMed": "string"}' -H "Content-Type:application/json"
# Out:
# {"error":"Field `admission_id` missing from request: {'patient_id': 0, 'race': 'string', 'gender': 'string', 'age': 'string', 'weight': 'string', 'admission_type_code': 0, 'discharge_disposition_code': 0, 'admission_source_code': 0, 'time_in_hospital': 0, 'payer_code': 'string', 'medical_specialty': 'string', 'has_prosthesis': True, 'complete_vaccination_status': 'string', 'num_lab_procedures': 0, 'num_procedures': 0, 'num_medications': 0, 'number_outpatient': 0, 'number_emergency': 0, 'number_inpatient': 0, 'diag_1': 'string', 'diag_2': 'string', 'diag_3': 'string', 'number_diagnoses': 0, 'blood_type': 'string', 'hemoglobin_level': 0, 'blood_transfusion': True, 'max_glu_serum': 'string', 'A1Cresult': 'string', 'diuretics': 'string', 'insulin': 'string', 'change': 'string', 'diabetesMed': 'string'}"}

# %%
! curl -X POST https://capstone-amilas.herokuapp.com/update -d '{"admission_id": 2110125.0, "readmitted": "Yes"}' -H "Content-Type:application/json"
# Out:
# {"error":"Admission ID: 2110125.0 does not exist"}

# %%
! curl -X POST http://localhost:5000/predict -d '{"admission_id": 10112, "patient_id": 0, "race": "string", "gender": "string", "age": "string", "weight": "string", "admission_type_code": 0, "discharge_disposition_code": 0,"admission_source_code": 0,"time_in_hospital": 0,"payer_code": "string","medical_specialty": "string","has_prosthesis": true,"complete_vaccination_status": "string","num_lab_procedures": 0,"num_procedures": 0,"num_medications": 0,"number_outpatient": 0,"number_emergency": 0,"number_inpatient": 0,"diag_1": "string","diag_2": "string","diag_3": "string","number_diagnoses": 0,"blood_type": "string","hemoglobin_level": 0,"blood_transfusion": true,"max_glu_serum": "string","A1Cresult": "string","diuretics": "string","insulin": "string","change": "string","diabetesMed": "string"}' -H "Content-Type:application/json"
# Out:
# {
#   "readmitted": "No",
#   "error": "ERROR: Admission ID: '10112' already exists"
# }

# %%
! curl -X POST http://localhost:5000/predict -d  '{"index": 20020, "admission_id": 92775, "patient_id": 107572680, "race": "Caucasian", "gender": "Female", "age": "[40-50)", "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 1, "time_in_hospital": 2, "payer_code": "CP", "medical_specialty": "InternalMedicine", "has_prosthesis": false, "complete_vaccination_status": "Complete", "num_lab_procedures": 61.0, "num_procedures": 0, "num_medications": 17.0, "number_outpatient": 0, "number_emergency": 0, "number_inpatient": 1, "diag_1": "250.03", "diag_2": "276", "diag_3": "401", "number_diagnoses": 8.0, "blood_type": "B-", "hemoglobin_level": 13.2, "blood_transfusion": false, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}' -H "Content-Type:application/json"
# Out:
# {
#   "readmitted": "No"
# }

# %%
! curl -X POST http://localhost:5000/predict -d '{"index": 20020.0, "admission_id": 9247701.0, "patient_id": 107572680.0, "race": "Caucasian", "gender": "Female", "age": null, "weight": "?", "admission_type_code": NaN, "discharge_disposition_code": 1.0, "admission_source_code": 1.0, "time_in_hospital": 2.0, "payer_code": "CP", "medical_specialty": "InternalMedicine", "has_prosthesis": 0.0, "complete_vaccination_status": "Complete", "num_lab_procedures": 61.0, "num_procedures": 0.0, "num_medications": 17.0, "number_outpatient": 0.0, "number_emergency": 0.0, "number_inpatient": 1.0, "diag_1": "250.03", "diag_2": "276", "diag_3": "401", "number_diagnoses": 8.0, "blood_type": "B-", "hemoglobin_level": 13.2, "blood_transfusion": 0.0, "max_glu_serum": "None", "A1Cresult": "None", "diuretics": "No", "insulin": "No", "change": "No", "diabetesMed": "No"}' -H "Content-Type:application/json"
# Out:
# {
#   "readmitted": "No",
#   "error": "ERROR: Admission ID: '9247701' already exists"
# }

# %%
! curl -X POST http://localhost:5000/predict -d "{'admission_id': 97435, 'patient_id': 85164714, 'race': 'Caucasian', 'gender': 'Male', 'age': '[60-70)', 'weight': '?', 'admission_type_code': 1.0, 'discharge_disposition_code': 6.0, 'admission_source_code': 7, 'time_in_hospital': 7, 'payer_code': 'BC', 'medical_specialty': '?', 'has_prosthesis': False, 'complete_vaccination_status': 'Complete', 'num_lab_procedures': 54.0, 'num_procedures': 0, 'num_medications': 15.0, 'number_outpatient': 0, 'number_emergency': 0, 'number_inpatient': 1, 'diag_1': '486', 'diag_2': '428', 'diag_3': '204', 'number_diagnoses': 9, 'blood_type': 'O+', 'hemoglobin_level': 13.6, 'blood_transfusion': False, 'max_glu_serum': 'None', 'A1Cresult': 'None', 'diuretics': 'No', 'insulin': 'No', 'change': 'No', 'diabetesMed': 'No'}" -H "Content-Type:application/json"
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>400 Bad Request</title>
# <h1>Bad Request</h1>
# <p>Failed to decode JSON object: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)</p>

# %%
! curl -X POST http://localhost:5000/update -d '{"admission_id": 9247701.0, "readmitted": "Yes"}' -H "Content-Type:application/json"
# Out:
# {
#   "admission_id": 9247701,
#   "actual_readmitted": "Yes",
#   "predicted_readmitted": "No"
# }

# %%
# Out:
# {"actual_readmitted":"Yes","admission_id":11,"predicted_readmitted":"No"}

# %%
! curl -X POST http://localhost:5000/predict -d request -H "Content-Type:application/json"
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>400 Bad Request</title>
# <h1>Bad Request</h1>
# <p>Failed to decode JSON object: Expecting value: line 1 column 1 (char 0)</p>

# %%
{'admission_id': 1,'patient_id': 91962954,'race': 'Caucasian','gender': 'Male','age': '[80-90)','weight': '?','admission_type_code': 2.0,'discharge_disposition_code': 1.0,'admission_source_code': 7,'time_in_hospital': 3,'payer_code': 'MC','medical_specialty': 'Emergency/Trauma','has_prosthesis': False,'complete_vaccination_status': 'Complete','num_lab_procedures': 50.0,'num_procedures': 0,'num_medications': 8.0,'number_outpatient': 0,'number_emergency': 0,'number_inpatient': 1,'diag_1': '276','diag_2': '507','diag_3': '150','number_diagnoses': 9,'blood_type': 'B+','hemoglobin_level': 15.7,'blood_transfusion': False,'max_glu_serum': 'None','A1Cresult': '>7','diuretics': 'No','insulin': 'No','change': 'No','diabetesMed': 'No'}
